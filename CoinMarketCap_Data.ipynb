# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pandas as pd

# %%
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'100',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': XXXX,
}

session = Session()
session.headers.update(headers)

try:
    response = session.get(url, params=parameters)
    data = json.loads(response.text)
    #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)

# %% [markdown]
# ### BTCUSD

# %%
pd.DataFrame(data['data'][0]['quote']).transpose()
# Out:
#                  last_updated   market_cap percent_change_1h  \
# USD  2021-06-17T13:15:02.000Z  7.25708e+11         -0.416163
#
#     percent_change_24h percent_change_30d percent_change_60d  \
# USD          -0.679412              -11.6            -29.613
#
#     percent_change_7d percent_change_90d    price   volume_24h
# USD           2.54245           -33.8959  38731.1  3.84039e+10

# %% [markdown]
# ### ETHUSD

# %%
pd.DataFrame(data['data'][1]['quote']).transpose()
# Out:
#                  last_updated   market_cap percent_change_1h  \
# USD  2021-06-17T13:15:02.000Z  2.77241e+11          -0.82538
#
#     percent_change_24h percent_change_30d percent_change_60d  \
# USD            -2.3276           -29.7593            12.5013
#
#     percent_change_7d percent_change_90d    price   volume_24h
# USD          -6.48827            31.6098  2383.27  2.26701e+10

# %%
pd.DataFrame(data['data'])
# Out:
#       id          name symbol          slug  num_market_pairs  \
# 0      1       Bitcoin    BTC       bitcoin              9093
# 1   1027      Ethereum    ETH      ethereum              5815
# 2    825        Tether   USDT        tether             12871
# 3   1839  Binance Coin    BNB  binance-coin               526
# 4   2010       Cardano    ADA       cardano               255
# ..   ...           ...    ...           ...               ...
# 95  1042       Siacoin     SC       siacoin                51
# 96  1808   OMG Network    OMG           omg               253
# 97  2087  KuCoin Token    KCS  kucoin-token                33
# 98  2099          ICON    ICX          icon                65
# 99  4779          HUSD   HUSD          husd                76
#
#                   date_added  \
# 0   2013-04-28T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2017-10-01T00:00:00.000Z
# ..                       ...
# 95  2015-08-26T00:00:00.000Z
# 96  2017-07-14T00:00:00.000Z
# 97  2017-10-24T00:00:00.000Z
# 98  2017-10-27T00:00:00.000Z
# 99  2019-10-15T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [mineable, pow, smart-contracts, ethereum, coi...           NaN
# 2   [payments, stablecoin, stablecoin-asset-backed...           NaN
# 3   [marketplace, centralized-exchange, payments, ...  1.705328e+08
# 4   [mineable, dpos, pos, platform, research, smar...  4.500000e+10
# ..                                                ...           ...
# 95  [mineable, pow, blake2b, platform, distributed...           NaN
# 96  [medium-of-exchange, payments, state-channels,...  1.402454e+08
# 97  [marketplace, centralized-exchange, discount-t...  1.701186e+08
# 98  [platform, enterprise-solutions, interoperabil...           NaN
# 99  [pow, medium-of-exchange, stablecoin, stableco...           NaN
#
#     circulating_supply  total_supply  \
# 0         1.873707e+07  1.873707e+07
# 1         1.163276e+08  1.163276e+08
# 2         6.255085e+10  6.447177e+10
# 3         1.534329e+08  1.694329e+08
# 4         3.194633e+10  3.270489e+10
# ..                 ...           ...
# 95        4.806929e+10  4.806929e+10
# 96        1.402454e+08  1.402454e+08
# 97        8.011864e+07  1.701186e+08
# 98        6.343383e+08  8.004600e+08
# 99        6.777606e+08  6.777606e+08
#
#                                              platform  cmc_rank  \
# 0                                                None         1
# 1                                                None         2
# 2   {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...         3
# 3                                                None         4
# 4                                                None         5
# ..                                                ...       ...
# 95                                               None        96
# 96                                               None        97
# 97  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...        98
# 98                                               None        99
# 99  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...       100
#
#                 last_updated  \
# 0   2021-06-17T13:15:02.000Z
# 1   2021-06-17T13:15:02.000Z
# 2   2021-06-17T13:14:08.000Z
# 3   2021-06-17T13:14:07.000Z
# 4   2021-06-17T13:14:09.000Z
# ..                       ...
# 95  2021-06-17T13:15:02.000Z
# 96  2021-06-17T13:14:08.000Z
# 97  2021-06-17T13:15:02.000Z
# 98  2021-06-17T13:15:02.000Z
# 99  2021-06-17T13:14:09.000Z
#
#                                                 quote
# 0   {'USD': {'price': 38731.148044868634, 'volume_...
# 1   {'USD': {'price': 2383.274490756754, 'volume_2...
# 2   {'USD': {'price': 1.000157972655, 'volume_24h'...
# 3   {'USD': {'price': 353.9722118940683, 'volume_2...
# 4   {'USD': {'price': 1.498079461829, 'volume_24h'...
# ..                                                ...
# 95  {'USD': {'price': 0.0151560334658, 'volume_24h...
# 96  {'USD': {'price': 5.18265271573975, 'volume_24...
# 97  {'USD': {'price': 8.93296190702047, 'volume_24...
# 98  {'USD': {'price': 1.12727194656547, 'volume_24...
# 99  {'USD': {'price': 1.00002982378944, 'volume_24...
#
# [100 rows x 14 columns]
